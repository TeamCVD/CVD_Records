# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.metrics
import pickle

print("Tensorlfow version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("GPU is", "available" if tf.test.is_gpu_available() else "NOT AVAILABLE")
# Out:
# WARNING:tensorflow:From <ipython-input-1-c66ca3651243>:10: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Tensorlfow version:  2.15.0
# Eager mode:  True
# GPU is available

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.listdir("/content/drive/My Drive/LSEG_Dataset")

file_path = "/content/drive/My Drive/LSEG_Dataset/cwe476_Data.csv"
df = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Generate random seed
#myrand=np.random.randint(1, 99999 + 1)
myrand=71926
np.random.seed(myrand)
tf.random.set_seed(myrand)
print("Random seed is:",myrand)
# Out:
# Random seed is: 71926

# %%
code_Data = df['code']

tokenizer = tf.keras.preprocessing.text.Tokenizer(char_level=False)
tokenizer.fit_on_texts(list(code_Data))
del(code_Data)
print('Number of tokens: ',len(tokenizer.word_counts))
# Out:
# Number of tokens:  1057833

# %%
sorted(tokenizer.word_counts.items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('intmarker', 3415435),
#  ('structpointermarker', 2830035),
#  ('if', 2721075),
#  ('0', 1875241),
#  ('return', 1616850),
#  ('charpointermarker', 1194054),
#  ('1', 1017843),
#  ('int', 913207),
#  ('tpointermarker', 911647),
#  ('null', 887802)]

# %%
INPUT_SIZE = 500

list_tokenized_train = tokenizer.texts_to_sequences(df['code'])
x_train = tf.keras.preprocessing.sequence.pad_sequences(list_tokenized_train,
                                  maxlen=INPUT_SIZE,
                                  padding='post')
x_train = x_train.astype(np.int64)

# %%
train_value_counts = pd.Series(train.iloc[:, 1]).value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-032569cf583b> in <cell line: 1>()
# ----> 1 train_value_counts = pd.Series(train.iloc[:, 1]).value_counts()
#
# NameError: name 'train' is not defined
